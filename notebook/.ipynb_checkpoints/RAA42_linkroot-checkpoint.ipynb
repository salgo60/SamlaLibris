# %% [markdown]
# * [#42](https://github.com/salgo60/SamlaLibris/issues/42)
# * [RAA42_linkroot.ipynb](https://github.com/salgo60/SamlaLibris/blob/master/notebook/RAA42_linkroot.ipynb)
#    *  links_raa_2025_11_30.html

# %%
import time

from datetime import datetime

now = datetime.now()
timestamp = now.timestamp()

start_time = time.time()
print("Start:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Start: 2025-11-30 13:41:18

# %%
SCRIPT_NAME = "RAA42_linkroot.ipynb"
SCRIPT_URL = (
    "https://github.com/salgo60/SamlaLibris/"
    "blob/master/Notebook/RAA42_linkroot.ipynb"
)

# %%
import os

# Get the current working directory
current_directory = os.getcwd()
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: /Users/salgo/Documents/GitHub/SamlaLibris/notebook

# %%
def read_domains(file_path):
    print(f"[DEBUG] Reading domains from: {file_path}")
    print(f"[DEBUG] Current Working Directory: {current_directory}")

    df = pd.read_csv(file_path, header=0)   # <- skip header row
    domains_list = df.iloc[:, 0].dropna().unique().tolist()
    print(f"[DEBUG] Found {len(domains_list)} domains.")
    return domains_list

# %%
import requests

def fetch_sitematrix_df():
    url = "https://meta.wikimedia.org/w/api.php"
    params = {
        "action": "sitematrix",
        "format": "json"
    }
    headers = {
        "User-Agent": "salgo60-language-fetcher/1.0 (salgo60@msn.com)"
    }

    print("[DEBUG] Fetching sitematrix…")
    r = requests.get(url, params=params, headers=headers)
    r.raise_for_status()

    if "application/json" not in r.headers.get("Content-Type", ""):
        raise ValueError("Server returned non-JSON response")

    data = r.json()["sitematrix"]

    rows = []

    # --- language-specific sites ---
    for key, lang_block in data.items():
        if not key.isdigit():
            continue  # skip "count", "specials"

        lang_code = lang_block.get("code")
        lang_name = lang_block.get("name")

        for site in lang_block.get("site", []):
            rows.append({
                "lang_code": lang_code,
                "lang_name": lang_name,
                "project": site.get("project"),
                "url": site.get("url"),
                "dbname": site.get("dbname"),
                "site_name": site.get("sitename"),
                "closed": site.get("closed", False)
            })

    # --- special wikis (Wikidata, Commons, Meta, etc.) ---
    for site in data.get("specials", []):
        rows.append({
            "lang_code": "special",
            "lang_name": "special",
            "project": site.get("project"),
            "url": site.get("url"),
            "dbname": site.get("dbname"),
            "site_name": site.get("sitename"),
            "closed": site.get("closed", False)
        })

    return pd.DataFrame(rows)

# %%
import requests
import pandas as pd


HEADERS = {
    "User-Agent": "salgo60-language-fetcher/2.0 (https://github.com/salgo60)"
}


df_wiki = fetch_sitematrix_df()
df_wiki["closed"] = df_wiki["closed"].fillna(False).astype(bool)
df_wiki = df_wiki[df_wiki["site_name"] == "Wikipedia"]
df_wiki.head()
# Out:
# [DEBUG] Fetching sitematrix…
#    lang_code  lang_name project                        url   dbname  \
# 0         aa   Qafár af    None   https://aa.wikipedia.org   aawiki
# 5        ace       Acèh    None  https://ace.wikipedia.org  acewiki
# 7         af  Afrikaans    None   https://af.wikipedia.org   afwiki
# 11        ak       None    None   https://ak.wikipedia.org   akwiki
# 18       ami    Pangcah    None  https://ami.wikipedia.org  amiwiki
#
#     site_name  closed
# 0   Wikipedia   False
# 5   Wikipedia   False
# 7   Wikipedia   False
# 11  Wikipedia   False
# 18  Wikipedia   False

# %%
df_wiki.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 207 entries, 0 to 1061
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lang_code  207 non-null    object
#  1   lang_name  206 non-null    object
#  2   project    0 non-null      object
#  3   url        207 non-null    object
#  4   dbname     207 non-null    object
#  5   site_name  207 non-null    object
#  6   closed     207 non-null    bool
# dtypes: bool(1), object(6)
# memory usage: 11.5+ KB

# %%
len(df_wiki)
# Out:
# 207

# %%
# -----------------------------------------------------------
# Fetch exturlusage entries for one lang/domain
# -----------------------------------------------------------
def fetch_exturlusage(lang, domain):
    base = f"https://{lang}.wikipedia.org/w/api.php"
    params = {
        "action": "query",
        "format": "json",
        "list": "exturlusage",
        "euquery": domain,
        "eulimit": "max"
    }
    while True:
        r = session.get(base, params=params, timeout=10)
        try:
            data = r.json()
        except ValueError:
            print(f"[WARN] {lang}: JSON decode failed")
            break

        for item in data.get("query", {}).get("exturlusage", []):
            yield {
                "lang": lang,
                "page_title": item.get("title"),
                "url": item.get("url"),
                "wiki_link": f"https://{lang}.wikipedia.org/wiki/{item.get('title').replace(' ', '_')}"
            }

        if "continue" not in data:
            break
        params.update(data["continue"])
        time.sleep(0.3)

# %%
import os
import time
import random
import requests
import pandas as pd
from urllib.parse import urlparse
from tqdm.notebook import tqdm
file_path_domain = "sources/domains.csv"
domains = read_domains(file_path_domain)
print(domains)
# Out:
# [DEBUG] Reading domains from: sources/domains.csv
# [DEBUG] Current Working Directory: /Users/salgo/Documents/GitHub/SamlaLibris/notebook
# [DEBUG] Found 6 domains.
# ['raa.se', 'kringla.nu', 'fornsok.se', 'kulturnav.org', 'k-samsok.se', 'kulturmiljolagen.se']

# %%
# -------------------------
# Session & helpers
# -------------------------
session = requests.Session()
session.headers.update(
    {"User-Agent": "RAA-LinkAudit/1.0 salgo60@msn.com"}
)

# Filter out special languages
df_wiki_lang = df_wiki[df_wiki["lang_code"] != "special"]
print("Antal Språk:", len(df_wiki_lang))

results = []

for _, row in df_wiki_lang.iterrows():
    lang = row["lang_code"]
    url = row["url"]
    lang_name = row["lang_name"]

    before = len(results)
    for d in domains:
        #print(lang, url, lang_name, d)

        for entry in fetch_exturlusage(lang, d):
            entry["domain"] = d
            entry["lang_code"] = lang
            entry["lang_name"] = lang_name
            results.append(entry)

    added = len(results) - before
    print(lang, lang_name, "-", added)
# Out:
# Antal Språk: 184
# aa https://aa.wikipedia.org Qafár af raa.se
# aa https://aa.wikipedia.org Qafár af kringla.nu
# aa https://aa.wikipedia.org Qafár af fornsok.se
# aa https://aa.wikipedia.org Qafár af kulturnav.org
# aa https://aa.wikipedia.org Qafár af k-samsok.se
# aa https://aa.wikipedia.org Qafár af kulturmiljolagen.se
# aa Qafár af - 0
# ace https://ace.wikipedia.org Acèh raa.se
# ace https://ace.wikipedia.org Acèh kringla.nu
# ace https://ace.wikipedia.org Acèh fornsok.se
# ace https://ace.wikipedia.org Acèh kulturnav.org
# ace https://ace.wikipedia.org Acèh k-samsok.se
# ace https://ace.wikipedia.org Acèh kulturmiljolagen.se
# ace Acèh - 3
# af https://af.wikipedia.org Afrikaans raa.se
# af https://af.wikipedia.org Afrikaans kringla.nu
# af https://af.wikipedia.org Afrikaans fornsok.se
# af https://af.wikipedia.org Afrikaans kulturnav.org
# af https://af.wikipedia.org Afrikaans k-samsok.se
# af https://af.wikipedia.org Afrikaans kulturmiljolagen.se
# af Afrikaans - 1118
# ak https://ak.wikipedia.org None raa.se
# ak https://ak.wikipedia.org None kringla.nu
# ak https://ak.wikipedia.org None fornsok.se
# ak https://ak.wikipedia.org None kulturnav.org
# ak https://ak.wikipedia.org None k-samsok.se
# ak https://ak.wikipedia.org None kulturmiljolagen.se
# ak None - 0
# ami https://ami.wikipedia.org Pangcah raa.se
# ami https://ami.wikipedia.org Pangcah kringla.nu
# ami https://ami.wikipedia.org Pangcah fornsok.se
# ami https://ami.wikipedia.org Pangcah kulturnav.org
# ami https://ami.wikipedia.org Pangcah k-samsok.se
# ami https://ami.wikipedia.org Pangcah kulturmiljolagen.se
# ami Pangcah - 0
# an https://an.wikipedia.org aragonés raa.se
# an https://an.wikipedia.org aragonés kringla.nu
# an https://an.wikipedia.org aragonés fornsok.se
# an https://an.wikipedia.org aragonés kulturnav.org
# an https://an.wikipedia.org aragonés k-samsok.se
# an https://an.wikipedia.org aragonés kulturmiljolagen.se
# an aragonés - 845
# ast https://ast.wikipedia.org asturianu raa.se
# ast https://ast.wikipedia.org asturianu kringla.nu
# ast https://ast.wikipedia.org asturianu fornsok.se
# ast https://ast.wikipedia.org asturianu kulturnav.org
# ast https://ast.wikipedia.org asturianu k-samsok.se
# ast https://ast.wikipedia.org asturianu kulturmiljolagen.se
# ast asturianu - 984
# av https://av.wikipedia.org авар raa.se
# av https://av.wikipedia.org авар kringla.nu
# av https://av.wikipedia.org авар fornsok.se
# av https://av.wikipedia.org авар kulturnav.org
# av https://av.wikipedia.org авар k-samsok.se
# av https://av.wikipedia.org авар kulturmiljolagen.se
# av авар - 11
# avk https://avk.wikipedia.org Kotava raa.se
# avk https://avk.wikipedia.org Kotava kringla.nu
# avk https://avk.wikipedia.org Kotava fornsok.se
# avk https://avk.wikipedia.org Kotava kulturnav.org
# avk https://avk.wikipedia.org Kotava k-samsok.se
# avk https://avk.wikipedia.org Kotava kulturmiljolagen.se
# avk Kotava - 0
# ay https://ay.wikipedia.org Aymar aru raa.se
# ay https://ay.wikipedia.org Aymar aru kringla.nu
# ay https://ay.wikipedia.org Aymar aru fornsok.se
# ay https://ay.wikipedia.org Aymar aru kulturnav.org
# ay https://ay.wikipedia.org Aymar aru k-samsok.se
# ay https://ay.wikipedia.org Aymar aru kulturmiljolagen.se
# ay Aymar aru - 0
# bar https://bar.wikipedia.org Boarisch raa.se
# bar https://bar.wikipedia.org Boarisch kringla.nu
# bar https://bar.wikipedia.org Boarisch fornsok.se
# bar https://bar.wikipedia.org Boarisch kulturnav.org
# bar https://bar.wikipedia.org Boarisch k-samsok.se
# bar https://bar.wikipedia.org Boarisch kulturmiljolagen.se
# bar Boarisch - 1
# bbc https://bbc.wikipedia.org Batak Toba raa.se
# bbc https://bbc.wikipedia.org Batak Toba kringla.nu
# bbc https://bbc.wikipedia.org Batak Toba fornsok.se
# bbc https://bbc.wikipedia.org Batak Toba kulturnav.org
# bbc https://bbc.wikipedia.org Batak Toba k-samsok.se
# bbc https://bbc.wikipedia.org Batak Toba kulturmiljolagen.se
# bbc Batak Toba - 0
# bcl https://bcl.wikipedia.org Bikol Central raa.se
# bcl https://bcl.wikipedia.org Bikol Central kringla.nu
# bcl https://bcl.wikipedia.org Bikol Central fornsok.se
# bcl https://bcl.wikipedia.org Bikol Central kulturnav.org
# bcl https://bcl.wikipedia.org Bikol Central k-samsok.se
# bcl https://bcl.wikipedia.org Bikol Central kulturmiljolagen.se
# bcl Bikol Central - 22
# bi https://bi.wikipedia.org Bislama raa.se
# bi https://bi.wikipedia.org Bislama kringla.nu
# bi https://bi.wikipedia.org Bislama fornsok.se
# bi https://bi.wikipedia.org Bislama kulturnav.org
# bi https://bi.wikipedia.org Bislama k-samsok.se
# bi https://bi.wikipedia.org Bislama kulturmiljolagen.se
# bi Bislama - 0
# bm https://bm.wikipedia.org bamanankan raa.se
# bm https://bm.wikipedia.org bamanankan kringla.nu
# bm https://bm.wikipedia.org bamanankan fornsok.se
# bm https://bm.wikipedia.org bamanankan kulturnav.org
# bm https://bm.wikipedia.org bamanankan k-samsok.se
# bm https://bm.wikipedia.org bamanankan kulturmiljolagen.se
# bm bamanankan - 0
# bo https://bo.wikipedia.org བོད་ཡིག raa.se
# bo https://bo.wikipedia.org བོད་ཡིག kringla.nu
# bo https://bo.wikipedia.org བོད་ཡིག fornsok.se
# bo https://bo.wikipedia.org བོད་ཡིག kulturnav.org
# bo https://bo.wikipedia.org བོད་ཡིག k-samsok.se
# bo https://bo.wikipedia.org བོད་ཡིག kulturmiljolagen.se
# bo བོད་ཡིག - 0
# br https://br.wikipedia.org brezhoneg raa.se
# br https://br.wikipedia.org brezhoneg kringla.nu
# br https://br.wikipedia.org brezhoneg fornsok.se
# br https://br.wikipedia.org brezhoneg kulturnav.org
# br https://br.wikipedia.org brezhoneg k-samsok.se
# br https://br.wikipedia.org brezhoneg kulturmiljolagen.se
# br brezhoneg - 0
# bs https://bs.wikipedia.org bosanski raa.se
# bs https://bs.wikipedia.org bosanski kringla.nu
# bs https://bs.wikipedia.org bosanski fornsok.se
# bs https://bs.wikipedia.org bosanski kulturnav.org
# bs https://bs.wikipedia.org bosanski k-samsok.se
# bs https://bs.wikipedia.org bosanski kulturmiljolagen.se
# bs bosanski - 384
# btm https://btm.wikipedia.org Batak Mandailing raa.se
# btm https://btm.wikipedia.org Batak Mandailing kringla.nu
# btm https://btm.wikipedia.org Batak Mandailing fornsok.se
# btm https://btm.wikipedia.org Batak Mandailing kulturnav.org
# btm https://btm.wikipedia.org Batak Mandailing k-samsok.se
# btm https://btm.wikipedia.org Batak Mandailing kulturmiljolagen.se
# btm Batak Mandailing - 0
# bug https://bug.wikipedia.org Basa Ugi raa.se
# bug https://bug.wikipedia.org Basa Ugi kringla.nu
# bug https://bug.wikipedia.org Basa Ugi fornsok.se
# bug https://bug.wikipedia.org Basa Ugi kulturnav.org
# bug https://bug.wikipedia.org Basa Ugi k-samsok.se
# bug https://bug.wikipedia.org Basa Ugi kulturmiljolagen.se
# bug Basa Ugi - 0
# bxr https://bxr.wikipedia.org буряад raa.se
# bxr https://bxr.wikipedia.org буряад kringla.nu
# bxr https://bxr.wikipedia.org буряад fornsok.se
# bxr https://bxr.wikipedia.org буряад kulturnav.org
# bxr https://bxr.wikipedia.org буряад k-samsok.se
# bxr https://bxr.wikipedia.org буряад kulturmiljolagen.se
# bxr буряад - 0
# cbk-zam https://cbk-zam.wikipedia.org Chavacano de Zamboanga raa.se
# cbk-zam https://cbk-zam.wikipedia.org Chavacano de Zamboanga kringla.nu
# cbk-zam https://cbk-zam.wikipedia.org Chavacano de Zamboanga fornsok.se
# cbk-zam https://cbk-zam.wikipedia.org Chavacano de Zamboanga kulturnav.org
# cbk-zam https://cbk-zam.wikipedia.org Chavacano de Zamboanga k-samsok.se
# cbk-zam https://cbk-zam.wikipedia.org Chavacano de Zamboanga kulturmiljolagen.se
# cbk-zam Chavacano de Zamboanga - 0
# cdo https://cdo.wikipedia.org 閩東語 / Mìng-dĕ̤ng-ngṳ̄ raa.se
# cdo https://cdo.wikipedia.org 閩東語 / Mìng-dĕ̤ng-ngṳ̄ kringla.nu
# cdo https://cdo.wikipedia.org 閩東語 / Mìng-dĕ̤ng-ngṳ̄ fornsok.se
# cdo https://cdo.wikipedia.org 閩東語 / Mìng-dĕ̤ng-ngṳ̄ kulturnav.org
# cdo https://cdo.wikipedia.org 閩東語 / Mìng-dĕ̤ng-ngṳ̄ k-samsok.se
# cdo https://cdo.wikipedia.org 閩東語 / Mìng-dĕ̤ng-ngṳ̄ kulturmiljolagen.se
# cdo 閩東語 / Mìng-dĕ̤ng-ngṳ̄ - 304
# ceb https://ceb.wikipedia.org Cebuano raa.se
# ceb https://ceb.wikipedia.org Cebuano kringla.nu
# ceb https://ceb.wikipedia.org Cebuano fornsok.se
# ceb https://ceb.wikipedia.org Cebuano kulturnav.org
# ceb https://ceb.wikipedia.org Cebuano k-samsok.se
# ceb https://ceb.wikipedia.org Cebuano kulturmiljolagen.se
# ceb Cebuano - 5
# ch https://ch.wikipedia.org Chamoru raa.se
# ch https://ch.wikipedia.org Chamoru kringla.nu
# ch https://ch.wikipedia.org Chamoru fornsok.se
# ch https://ch.wikipedia.org Chamoru kulturnav.org
# ch https://ch.wikipedia.org Chamoru k-samsok.se
# ch https://ch.wikipedia.org Chamoru kulturmiljolagen.se
# ch Chamoru - 0
# cho https://cho.wikipedia.org Chahta anumpa raa.se
# cho https://cho.wikipedia.org Chahta anumpa kringla.nu
# cho https://cho.wikipedia.org Chahta anumpa fornsok.se
# cho https://cho.wikipedia.org Chahta anumpa kulturnav.org
# gor https://gor.wikipedia.org Bahasa Hulontalo kulturnav.org
# gor https://gor.wikipedia.org Bahasa Hulontalo k-samsok.se
# gor https://gor.wikipedia.org Bahasa Hulontalo kulturmiljolagen.se
# gor Bahasa Hulontalo - 0
# got https://got.wikipedia.org 𐌲𐌿𐍄𐌹𐍃𐌺 raa.se
# got https://got.wikipedia.org 𐌲𐌿𐍄𐌹𐍃𐌺 kringla.nu
# got https://got.wikipedia.org 𐌲𐌿𐍄𐌹𐍃𐌺 fornsok.se
# got https://got.wikipedia.org 𐌲𐌿𐍄𐌹𐍃𐌺 kulturnav.org
# got https://got.wikipedia.org 𐌲𐌿𐍄𐌹𐍃𐌺 k-samsok.se
# got https://got.wikipedia.org 𐌲𐌿𐍄𐌹𐍃𐌺 kulturmiljolagen.se
# got 𐌲𐌿𐍄𐌹𐍃𐌺 - 0
# gpe https://gpe.wikipedia.org Ghanaian Pidgin raa.se
# gpe https://gpe.wikipedia.org Ghanaian Pidgin kringla.nu
# gpe https://gpe.wikipedia.org Ghanaian Pidgin fornsok.se
# gpe https://gpe.wikipedia.org Ghanaian Pidgin kulturnav.org
# gpe https://gpe.wikipedia.org Ghanaian Pidgin k-samsok.se
# gpe https://gpe.wikipedia.org Ghanaian Pidgin kulturmiljolagen.se
# gpe Ghanaian Pidgin - 56
# gsw https://als.wikipedia.org Alemannisch raa.se
# [WARN] gsw: JSON decode failed
# gsw https://als.wikipedia.org Alemannisch kringla.nu
# [WARN] gsw: JSON decode failed
# gsw https://als.wikipedia.org Alemannisch fornsok.se
# [WARN] gsw: JSON decode failed
# gsw https://als.wikipedia.org Alemannisch kulturnav.org
# [WARN] gsw: JSON decode failed
# gsw https://als.wikipedia.org Alemannisch k-samsok.se
# [WARN] gsw: JSON decode failed
# gsw https://als.wikipedia.org Alemannisch kulturmiljolagen.se
# [WARN] gsw: JSON decode failed
# gsw Alemannisch - 0
# guw https://guw.wikipedia.org gungbe raa.se
# guw https://guw.wikipedia.org gungbe kringla.nu
# guw https://guw.wikipedia.org gungbe fornsok.se
# guw https://guw.wikipedia.org gungbe kulturnav.org
# guw https://guw.wikipedia.org gungbe k-samsok.se
# guw https://guw.wikipedia.org gungbe kulturmiljolagen.se
# guw gungbe - 1
# gv https://gv.wikipedia.org Gaelg raa.se
# gv https://gv.wikipedia.org Gaelg kringla.nu
# gv https://gv.wikipedia.org Gaelg fornsok.se
# gv https://gv.wikipedia.org Gaelg kulturnav.org
# gv https://gv.wikipedia.org Gaelg k-samsok.se
# gv https://gv.wikipedia.org Gaelg kulturmiljolagen.se
# gv Gaelg - 321
# ha https://ha.wikipedia.org Hausa raa.se
# ha https://ha.wikipedia.org Hausa kringla.nu
# ha https://ha.wikipedia.org Hausa fornsok.se
# ha https://ha.wikipedia.org Hausa kulturnav.org
# ha https://ha.wikipedia.org Hausa k-samsok.se
# ha https://ha.wikipedia.org Hausa kulturmiljolagen.se
# ha Hausa - 17
# hak https://hak.wikipedia.org 客家語 / Hak-kâ-ngî raa.se
# id Bahasa Indonesia - 2550
# ie https://ie.wikipedia.org Interlingue raa.se
# ie https://ie.wikipedia.org Interlingue kringla.nu
# ie https://ie.wikipedia.org Interlingue fornsok.se
# ie https://ie.wikipedia.org Interlingue kulturnav.org
# ie https://ie.wikipedia.org Interlingue k-samsok.se
# ie https://ie.wikipedia.org Interlingue kulturmiljolagen.se
# ie Interlingue - 0
# ig https://ig.wikipedia.org Igbo raa.se
# ig https://ig.wikipedia.org Igbo kringla.nu
# ig https://ig.wikipedia.org Igbo fornsok.se
# ig https://ig.wikipedia.org Igbo kulturnav.org
# ig https://ig.wikipedia.org Igbo k-samsok.se
# ig https://ig.wikipedia.org Igbo kulturmiljolagen.se
# ig Igbo - 10
# ii https://ii.wikipedia.org ꆇꉙ raa.se
# ii https://ii.wikipedia.org ꆇꉙ kringla.nu
# ii https://ii.wikipedia.org ꆇꉙ fornsok.se
# ii https://ii.wikipedia.org ꆇꉙ kulturnav.org
# ii https://ii.wikipedia.org ꆇꉙ k-samsok.se
# ii https://ii.wikipedia.org ꆇꉙ kulturmiljolagen.se
# ii ꆇꉙ - 0
# ik https://ik.wikipedia.org Iñupiatun raa.se
# ik https://ik.wikipedia.org Iñupiatun kringla.nu
# ik https://ik.wikipedia.org Iñupiatun fornsok.se
# ik https://ik.wikipedia.org Iñupiatun kulturnav.org
# ik https://ik.wikipedia.org Iñupiatun k-samsok.se
# ik https://ik.wikipedia.org Iñupiatun kulturmiljolagen.se
# ik Iñupiatun - 0
# ilo https://ilo.wikipedia.org Ilokano raa.se
# ilo https://ilo.wikipedia.org Ilokano kringla.nu
# ilo https://ilo.wikipedia.org Ilokano fornsok.se
# ilo https://ilo.wikipedia.org Ilokano kulturnav.org
# ilo https://ilo.wikipedia.org Ilokano k-samsok.se
# ilo https://ilo.wikipedia.org Ilokano kulturmiljolagen.se
# ilo Ilokano - 313
# is https://is.wikipedia.org íslenska raa.se
# is https://is.wikipedia.org íslenska kringla.nu
# is https://is.wikipedia.org íslenska fornsok.se
# is https://is.wikipedia.org íslenska kulturnav.org
# is https://is.wikipedia.org íslenska k-samsok.se
# is https://is.wikipedia.org íslenska kulturmiljolagen.se
# is íslenska - 0
# it https://it.wikipedia.org italiano raa.se
# it https://it.wikipedia.org italiano kringla.nu
# it https://it.wikipedia.org italiano fornsok.se
# it https://it.wikipedia.org italiano kulturnav.org
# it https://it.wikipedia.org italiano k-samsok.se
# it https://it.wikipedia.org italiano kulturmiljolagen.se
# it italiano - 125
# ja https://ja.wikipedia.org 日本語 raa.se
# ja https://ja.wikipedia.org 日本語 kringla.nu
# ja https://ja.wikipedia.org 日本語 fornsok.se
# ja https://ja.wikipedia.org 日本語 kulturnav.org
# ja https://ja.wikipedia.org 日本語 k-samsok.se
# ja https://ja.wikipedia.org 日本語 kulturmiljolagen.se
# ja 日本語 - 4305
# jbo https://jbo.wikipedia.org la .lojban. raa.se
# jbo https://jbo.wikipedia.org la .lojban. kringla.nu
# pwn https://pwn.wikipedia.org pinayuanan kringla.nu
# pwn https://pwn.wikipedia.org pinayuanan fornsok.se
# pwn https://pwn.wikipedia.org pinayuanan kulturnav.org
# pwn https://pwn.wikipedia.org pinayuanan k-samsok.se
# pwn https://pwn.wikipedia.org pinayuanan kulturmiljolagen.se
# pwn pinayuanan - 0
# qu https://qu.wikipedia.org Runa Simi raa.se
# qu https://qu.wikipedia.org Runa Simi kringla.nu
# qu https://qu.wikipedia.org Runa Simi fornsok.se
# qu https://qu.wikipedia.org Runa Simi kulturnav.org
# qu https://qu.wikipedia.org Runa Simi k-samsok.se
# qu https://qu.wikipedia.org Runa Simi kulturmiljolagen.se
# qu Runa Simi - 0
# rm https://rm.wikipedia.org rumantsch raa.se
# rm https://rm.wikipedia.org rumantsch kringla.nu
# rm https://rm.wikipedia.org rumantsch fornsok.se
# rm https://rm.wikipedia.org rumantsch kulturnav.org
# rm https://rm.wikipedia.org rumantsch k-samsok.se
# rm https://rm.wikipedia.org rumantsch kulturmiljolagen.se
# rm rumantsch - 0
# rn https://rn.wikipedia.org ikirundi raa.se
# rn https://rn.wikipedia.org ikirundi kringla.nu
# rn https://rn.wikipedia.org ikirundi fornsok.se
# rn https://rn.wikipedia.org ikirundi kulturnav.org
# rn https://rn.wikipedia.org ikirundi k-samsok.se
# rn https://rn.wikipedia.org ikirundi kulturmiljolagen.se
# rn ikirundi - 0
# ro https://ro.wikipedia.org română raa.se
# ro https://ro.wikipedia.org română kringla.nu
# ro https://ro.wikipedia.org română fornsok.se
# ro https://ro.wikipedia.org română kulturnav.org
# ro https://ro.wikipedia.org română k-samsok.se
# ro https://ro.wikipedia.org română kulturmiljolagen.se
# ro română - 1984
# roa-tara https://roa-tara.wikipedia.org tarandíne raa.se
# roa-tara https://roa-tara.wikipedia.org tarandíne kringla.nu
# roa-tara https://roa-tara.wikipedia.org tarandíne fornsok.se
# roa-tara https://roa-tara.wikipedia.org tarandíne kulturnav.org
# roa-tara https://roa-tara.wikipedia.org tarandíne k-samsok.se
# roa-tara https://roa-tara.wikipedia.org tarandíne kulturmiljolagen.se
# roa-tara tarandíne - 0
# rup https://roa-rup.wikipedia.org armãneashti raa.se
# [WARN] rup: JSON decode failed
# rup https://roa-rup.wikipedia.org armãneashti kringla.nu
# [WARN] rup: JSON decode failed
# rup https://roa-rup.wikipedia.org armãneashti fornsok.se
# [WARN] rup: JSON decode failed
# rup https://roa-rup.wikipedia.org armãneashti kulturnav.org
# [WARN] rup: JSON decode failed
# rup https://roa-rup.wikipedia.org armãneashti k-samsok.se
# [WARN] rup: JSON decode failed
# rup https://roa-rup.wikipedia.org armãneashti kulturmiljolagen.se
# [WARN] rup: JSON decode failed
# rup armãneashti - 0
# rw https://rw.wikipedia.org Ikinyarwanda raa.se
# rw https://rw.wikipedia.org Ikinyarwanda kringla.nu
# rw https://rw.wikipedia.org Ikinyarwanda fornsok.se
# rw https://rw.wikipedia.org Ikinyarwanda kulturnav.org
# rw https://rw.wikipedia.org Ikinyarwanda k-samsok.se
# rw https://rw.wikipedia.org Ikinyarwanda kulturmiljolagen.se
# rw Ikinyarwanda - 0
# sc https://sc.wikipedia.org sardu raa.se
# sc https://sc.wikipedia.org sardu kringla.nu
# sc https://sc.wikipedia.org sardu fornsok.se
# sc https://sc.wikipedia.org sardu kulturnav.org
# sc https://sc.wikipedia.org sardu k-samsok.se
# sc https://sc.wikipedia.org sardu kulturmiljolagen.se
# sc sardu - 54
# scn https://scn.wikipedia.org sicilianu raa.se
# scn https://scn.wikipedia.org sicilianu kringla.nu
# scn https://scn.wikipedia.org sicilianu fornsok.se
# scn https://scn.wikipedia.org sicilianu kulturnav.org
# scn https://scn.wikipedia.org sicilianu k-samsok.se
# scn https://scn.wikipedia.org sicilianu kulturmiljolagen.se
# scn sicilianu - 0
# sco https://sco.wikipedia.org Scots raa.se
# sco https://sco.wikipedia.org Scots kringla.nu
# sco https://sco.wikipedia.org Scots fornsok.se
# sco https://sco.wikipedia.org Scots kulturnav.org
# sco https://sco.wikipedia.org Scots k-samsok.se
# sco https://sco.wikipedia.org Scots kulturmiljolagen.se
# sco Scots - 177
# se https://se.wikipedia.org davvisámegiella raa.se
# se https://se.wikipedia.org davvisámegiella kringla.nu
# se https://se.wikipedia.org davvisámegiella fornsok.se
# se https://se.wikipedia.org davvisámegiella kulturnav.org
# se https://se.wikipedia.org davvisámegiella k-samsok.se
# se https://se.wikipedia.org davvisámegiella kulturmiljolagen.se
# se davvisámegiella - 19
# sg https://sg.wikipedia.org Sängö raa.se
# sg https://sg.wikipedia.org Sängö kringla.nu
# sg https://sg.wikipedia.org Sängö fornsok.se
# sg https://sg.wikipedia.org Sängö kulturnav.org
# sg https://sg.wikipedia.org Sängö k-samsok.se
# sg https://sg.wikipedia.org Sängö kulturmiljolagen.se
# sg Sängö - 0
# sgs https://bat-smg.wikipedia.org žemaitėška raa.se
# sgs https://bat-smg.wikipedia.org žemaitėška kringla.nu
# sgs https://bat-smg.wikipedia.org žemaitėška fornsok.se
# sgs https://bat-smg.wikipedia.org žemaitėška kulturnav.org
# sgs https://bat-smg.wikipedia.org žemaitėška k-samsok.se
# sgs https://bat-smg.wikipedia.org žemaitėška kulturmiljolagen.se
# sgs žemaitėška - 0
# shi https://shi.wikipedia.org Taclḥit raa.se
# shi https://shi.wikipedia.org Taclḥit kringla.nu
# shi https://shi.wikipedia.org Taclḥit fornsok.se
# shi https://shi.wikipedia.org Taclḥit kulturnav.org
# shi https://shi.wikipedia.org Taclḥit k-samsok.se
# shi https://shi.wikipedia.org Taclḥit kulturmiljolagen.se
# shi Taclḥit - 0
# simple https://simple.wikipedia.org Simple English raa.se
# simple https://simple.wikipedia.org Simple English kringla.nu
# simple https://simple.wikipedia.org Simple English fornsok.se
# simple https://simple.wikipedia.org Simple English kulturnav.org
# simple https://simple.wikipedia.org Simple English k-samsok.se
# simple https://simple.wikipedia.org Simple English kulturmiljolagen.se
# simple Simple English - 509
# sm https://sm.wikipedia.org Gagana Samoa raa.se
# stq https://stq.wikipedia.org Seeltersk k-samsok.se
# stq https://stq.wikipedia.org Seeltersk kulturmiljolagen.se
# stq Seeltersk - 0
# su https://su.wikipedia.org Sunda raa.se
# su https://su.wikipedia.org Sunda kringla.nu
# su https://su.wikipedia.org Sunda fornsok.se
# su https://su.wikipedia.org Sunda kulturnav.org
# su https://su.wikipedia.org Sunda k-samsok.se
# su https://su.wikipedia.org Sunda kulturmiljolagen.se
# su Sunda - 10
# sv https://sv.wikipedia.org svenska raa.se
# sv https://sv.wikipedia.org svenska kringla.nu
# sv https://sv.wikipedia.org svenska fornsok.se
# sv https://sv.wikipedia.org svenska kulturnav.org
# sv https://sv.wikipedia.org svenska k-samsok.se
# sv https://sv.wikipedia.org svenska kulturmiljolagen.se
# sv svenska - 28652
# sw https://sw.wikipedia.org Kiswahili raa.se
# sw https://sw.wikipedia.org Kiswahili kringla.nu
# sw https://sw.wikipedia.org Kiswahili fornsok.se
# sw https://sw.wikipedia.org Kiswahili kulturnav.org
# sw https://sw.wikipedia.org Kiswahili k-samsok.se
# sw https://sw.wikipedia.org Kiswahili kulturmiljolagen.se
# sw Kiswahili - 1
# szl https://szl.wikipedia.org ślůnski raa.se
# szl https://szl.wikipedia.org ślůnski kringla.nu
# szl https://szl.wikipedia.org ślůnski fornsok.se
# szl https://szl.wikipedia.org ślůnski kulturnav.org
# szl https://szl.wikipedia.org ślůnski k-samsok.se
# szl https://szl.wikipedia.org ślůnski kulturmiljolagen.se
# szl ślůnski - 0
# tet https://tet.wikipedia.org tetun raa.se
# tet https://tet.wikipedia.org tetun kringla.nu
# tet https://tet.wikipedia.org tetun fornsok.se
# tet https://tet.wikipedia.org tetun kulturnav.org
# tet https://tet.wikipedia.org tetun k-samsok.se
# tet https://tet.wikipedia.org tetun kulturmiljolagen.se
# tet tetun - 0
# tl https://tl.wikipedia.org Tagalog raa.se
# tl https://tl.wikipedia.org Tagalog kringla.nu
# tl https://tl.wikipedia.org Tagalog fornsok.se
# tl https://tl.wikipedia.org Tagalog kulturnav.org
# tl https://tl.wikipedia.org Tagalog k-samsok.se
# tl https://tl.wikipedia.org Tagalog kulturmiljolagen.se
# tl Tagalog - 127
# tn https://tn.wikipedia.org Setswana raa.se
# tn https://tn.wikipedia.org Setswana kringla.nu
# tn https://tn.wikipedia.org Setswana fornsok.se
# tn https://tn.wikipedia.org Setswana kulturnav.org
# tn https://tn.wikipedia.org Setswana k-samsok.se
# tn https://tn.wikipedia.org Setswana kulturmiljolagen.se
# tn Setswana - 0
# to https://to.wikipedia.org lea faka-Tonga raa.se
# to https://to.wikipedia.org lea faka-Tonga kringla.nu
# to https://to.wikipedia.org lea faka-Tonga fornsok.se
# to https://to.wikipedia.org lea faka-Tonga kulturnav.org
# to https://to.wikipedia.org lea faka-Tonga k-samsok.se
# to https://to.wikipedia.org lea faka-Tonga kulturmiljolagen.se
# to lea faka-Tonga - 0
# tpi https://tpi.wikipedia.org Tok Pisin raa.se
# tpi https://tpi.wikipedia.org Tok Pisin kringla.nu
# tpi https://tpi.wikipedia.org Tok Pisin fornsok.se
# tpi https://tpi.wikipedia.org Tok Pisin kulturnav.org
# tpi https://tpi.wikipedia.org Tok Pisin k-samsok.se
# tpi https://tpi.wikipedia.org Tok Pisin kulturmiljolagen.se
# tpi Tok Pisin - 0
# ts https://ts.wikipedia.org Xitsonga raa.se
# ts https://ts.wikipedia.org Xitsonga kringla.nu
# ts https://ts.wikipedia.org Xitsonga fornsok.se
# ts https://ts.wikipedia.org Xitsonga kulturnav.org
# ts https://ts.wikipedia.org Xitsonga k-samsok.se
# ts https://ts.wikipedia.org Xitsonga kulturmiljolagen.se
# ts Xitsonga - 0
# tt https://tt.wikipedia.org татарча / tatarça raa.se
# tt https://tt.wikipedia.org татарча / tatarça kringla.nu
# tt https://tt.wikipedia.org татарча / tatarça fornsok.se
# tt https://tt.wikipedia.org татарча / tatarça kulturnav.org
# tt https://tt.wikipedia.org татарча / tatarça k-samsok.se
# tt https://tt.wikipedia.org татарча / tatarça kulturmiljolagen.se
# tt татарча / tatarça - 45
# tum https://tum.wikipedia.org chiTumbuka raa.se
# tum https://tum.wikipedia.org chiTumbuka kringla.nu
# tum https://tum.wikipedia.org chiTumbuka fornsok.se
# tum https://tum.wikipedia.org chiTumbuka kulturnav.org
# tum https://tum.wikipedia.org chiTumbuka k-samsok.se
# tum https://tum.wikipedia.org chiTumbuka kulturmiljolagen.se
# tum chiTumbuka - 52
# tw https://tw.wikipedia.org Twi raa.se
# tw https://tw.wikipedia.org Twi kringla.nu
# tw https://tw.wikipedia.org Twi fornsok.se
# tw https://tw.wikipedia.org Twi kulturnav.org
# tw https://tw.wikipedia.org Twi k-samsok.se
# tw https://tw.wikipedia.org Twi kulturmiljolagen.se
# tw Twi - 0
# ty https://ty.wikipedia.org reo tahiti raa.se
# ty https://ty.wikipedia.org reo tahiti kringla.nu
# ty https://ty.wikipedia.org reo tahiti fornsok.se
# ty https://ty.wikipedia.org reo tahiti kulturnav.org
# ty https://ty.wikipedia.org reo tahiti k-samsok.se
# ty https://ty.wikipedia.org reo tahiti kulturmiljolagen.se
# ty reo tahiti - 0
# ug https://ug.wikipedia.org ئۇيغۇرچە / Uyghurche raa.se
# ug https://ug.wikipedia.org ئۇيغۇرچە / Uyghurche kringla.nu
# ug https://ug.wikipedia.org ئۇيغۇرچە / Uyghurche fornsok.se
# ug https://ug.wikipedia.org ئۇيغۇرچە / Uyghurche kulturnav.org
# ug https://ug.wikipedia.org ئۇيغۇرچە / Uyghurche k-samsok.se
# ug https://ug.wikipedia.org ئۇيغۇرچە / Uyghurche kulturmiljolagen.se
# ug ئۇيغۇرچە / Uyghurche - 0
# ve https://ve.wikipedia.org Tshivenda raa.se
# ve https://ve.wikipedia.org Tshivenda kringla.nu
# ve https://ve.wikipedia.org Tshivenda fornsok.se
# ve https://ve.wikipedia.org Tshivenda kulturnav.org
# ve https://ve.wikipedia.org Tshivenda k-samsok.se
# ve https://ve.wikipedia.org Tshivenda kulturmiljolagen.se
# ve Tshivenda - 0
# vec https://vec.wikipedia.org vèneto raa.se
# vec https://vec.wikipedia.org vèneto kringla.nu
# vec https://vec.wikipedia.org vèneto fornsok.se
# vec https://vec.wikipedia.org vèneto kulturnav.org
# vec https://vec.wikipedia.org vèneto k-samsok.se
# vec https://vec.wikipedia.org vèneto kulturmiljolagen.se
# vec vèneto - 0
# vi https://vi.wikipedia.org Tiếng Việt raa.se
# vi https://vi.wikipedia.org Tiếng Việt kringla.nu
# vi https://vi.wikipedia.org Tiếng Việt fornsok.se
# vi https://vi.wikipedia.org Tiếng Việt kulturnav.org
# vi https://vi.wikipedia.org Tiếng Việt k-samsok.se
# vi https://vi.wikipedia.org Tiếng Việt kulturmiljolagen.se
# vi Tiếng Việt - 455
# vls https://vls.wikipedia.org West-Vlams raa.se
# vls https://vls.wikipedia.org West-Vlams kringla.nu
# vls https://vls.wikipedia.org West-Vlams fornsok.se
# vls https://vls.wikipedia.org West-Vlams kulturnav.org
# vls https://vls.wikipedia.org West-Vlams k-samsok.se
# vls https://vls.wikipedia.org West-Vlams kulturmiljolagen.se
# vls West-Vlams - 0
# vro https://fiu-vro.wikipedia.org võro raa.se
# vro https://fiu-vro.wikipedia.org võro kringla.nu
# vro https://fiu-vro.wikipedia.org võro fornsok.se
# vro https://fiu-vro.wikipedia.org võro kulturnav.org
# vro https://fiu-vro.wikipedia.org võro k-samsok.se
# vro https://fiu-vro.wikipedia.org võro kulturmiljolagen.se
# vro võro - 0
# wa https://wa.wikipedia.org walon raa.se
# wa https://wa.wikipedia.org walon kringla.nu
# wa https://wa.wikipedia.org walon fornsok.se
# wa https://wa.wikipedia.org walon kulturnav.org
# wa https://wa.wikipedia.org walon k-samsok.se
# wa https://wa.wikipedia.org walon kulturmiljolagen.se
# wa walon - 0
# war https://war.wikipedia.org Winaray raa.se
# war https://war.wikipedia.org Winaray kringla.nu
# war https://war.wikipedia.org Winaray fornsok.se
# war https://war.wikipedia.org Winaray kulturnav.org
# war https://war.wikipedia.org Winaray k-samsok.se
# war https://war.wikipedia.org Winaray kulturmiljolagen.se
# war Winaray - 0
# wo https://wo.wikipedia.org Wolof raa.se
# wo https://wo.wikipedia.org Wolof kringla.nu
# wo https://wo.wikipedia.org Wolof fornsok.se
# wo https://wo.wikipedia.org Wolof kulturnav.org
# wo https://wo.wikipedia.org Wolof k-samsok.se
# wo https://wo.wikipedia.org Wolof kulturmiljolagen.se
# wo Wolof - 0
# xal https://xal.wikipedia.org хальмг raa.se
# xal https://xal.wikipedia.org хальмг kringla.nu
# xal https://xal.wikipedia.org хальмг fornsok.se
# xal https://xal.wikipedia.org хальмг kulturnav.org
# xal https://xal.wikipedia.org хальмг k-samsok.se
# xal https://xal.wikipedia.org хальмг kulturmiljolagen.se
# xal хальмг - 0
# xh https://xh.wikipedia.org isiXhosa raa.se
# xh https://xh.wikipedia.org isiXhosa kringla.nu
# xh https://xh.wikipedia.org isiXhosa fornsok.se
# xh https://xh.wikipedia.org isiXhosa kulturnav.org
# xh https://xh.wikipedia.org isiXhosa k-samsok.se
# xh https://xh.wikipedia.org isiXhosa kulturmiljolagen.se
# xh isiXhosa - 0
# yo https://yo.wikipedia.org Yorùbá raa.se
# yo https://yo.wikipedia.org Yorùbá kringla.nu
# yo https://yo.wikipedia.org Yorùbá fornsok.se
# yo https://yo.wikipedia.org Yorùbá kulturnav.org
# yo https://yo.wikipedia.org Yorùbá k-samsok.se
# yo https://yo.wikipedia.org Yorùbá kulturmiljolagen.se
# yo Yorùbá - 0
# za https://za.wikipedia.org Vahcuengh raa.se
# za https://za.wikipedia.org Vahcuengh kringla.nu
# za https://za.wikipedia.org Vahcuengh fornsok.se
# za https://za.wikipedia.org Vahcuengh kulturnav.org
# za https://za.wikipedia.org Vahcuengh k-samsok.se
# za https://za.wikipedia.org Vahcuengh kulturmiljolagen.se
# za Vahcuengh - 1
# zea https://zea.wikipedia.org Zeêuws raa.se
# zea https://zea.wikipedia.org Zeêuws kringla.nu
# zea https://zea.wikipedia.org Zeêuws fornsok.se
# zea https://zea.wikipedia.org Zeêuws kulturnav.org
# zea https://zea.wikipedia.org Zeêuws k-samsok.se
# zea https://zea.wikipedia.org Zeêuws kulturmiljolagen.se
# zea Zeêuws - 0
# zh https://zh.wikipedia.org 中文 raa.se
# zh https://zh.wikipedia.org 中文 kringla.nu
# zh https://zh.wikipedia.org 中文 fornsok.se
# zh https://zh.wikipedia.org 中文 kulturnav.org
# zh https://zh.wikipedia.org 中文 k-samsok.se
# zh https://zh.wikipedia.org 中文 kulturmiljolagen.se
# zh 中文 - 2126
# zu https://zu.wikipedia.org isiZulu raa.se
# zu https://zu.wikipedia.org isiZulu kringla.nu
# zu https://zu.wikipedia.org isiZulu fornsok.se
# zu https://zu.wikipedia.org isiZulu kulturnav.org
# zu https://zu.wikipedia.org isiZulu k-samsok.se
# zu https://zu.wikipedia.org isiZulu kulturmiljolagen.se
# zu isiZulu - 0

# %%
#results

# %%
domains
# Out:
# ['raa.se',
#  'kringla.nu',
#  'fornsok.se',
#  'kulturnav.org',
#  'k-samsok.se',
#  'kulturmiljolagen.se']

# %%
df_raa = pd.DataFrame(results)

# %%
df_raa
# Out:
#        lang          page_title  \
# 0       ace       Leonard Cohen
# 1       ace    Agnetha Fältskog
# 2       ace  Anni-Frid Lyngstad
# 3        af               Adils
# 4        af      Oscar Niemeyer
# ...     ...                 ...
# 113005   zh         阿克塞利·加伦-卡莱拉
# 113006   zh             路易-腓力一世
# 113007   zh        腓力二世 (奥尔良公爵)
# 113008   zh                  日本
# 113009   zh         約翰·米爾斯 (演員)
#
#                                                       url  \
# 0       http://kulturnav.org/language/en/7e908441-ad8d...
# 1       http://kulturnav.org/language/en/1718a400-a2bc...
# 2       http://kulturnav.org/language/en/a75e48ae-e70f...
# 3       http://www.raa.se/cms/extern/se_och_besoka/sev...
# 4       http://kulturnav.org/6aa00405-f813-4e04-96b2-1...
# ...                                                   ...
# 113005  http://kulturnav.org/05592038-b220-4690-a4b0-2...
# 113006  http://kulturnav.org/7996dfff-be63-44e5-a183-b...
# 113007  http://kulturnav.org/3ae5117c-3ef8-4d33-9eea-9...
# 113008  http://kulturnav.org/de944dd7-838e-46d0-a342-b...
# 113009  http://kulturnav.org/04ac3136-7fd5-470d-bb3e-0...
#
#                                                 wiki_link         domain  \
# 0            https://ace.wikipedia.org/wiki/Leonard_Cohen  kulturnav.org
# 1         https://ace.wikipedia.org/wiki/Agnetha_Fältskog  kulturnav.org
# 2       https://ace.wikipedia.org/wiki/Anni-Frid_Lyngstad  kulturnav.org
# 3                     https://af.wikipedia.org/wiki/Adils         raa.se
# 4            https://af.wikipedia.org/wiki/Oscar_Niemeyer  kulturnav.org
# ...                                                   ...            ...
# 113005          https://zh.wikipedia.org/wiki/阿克塞利·加伦-卡莱拉  kulturnav.org
# 113006              https://zh.wikipedia.org/wiki/路易-腓力一世  kulturnav.org
# 113007         https://zh.wikipedia.org/wiki/腓力二世_(奥尔良公爵)  kulturnav.org
# 113008                   https://zh.wikipedia.org/wiki/日本  kulturnav.org
# 113009          https://zh.wikipedia.org/wiki/約翰·米爾斯_(演員)  kulturnav.org
#
#        lang_code  lang_name
# 0            ace       Acèh
# 1            ace       Acèh
# 2            ace       Acèh
# 3             af  Afrikaans
# 4             af  Afrikaans
# ...          ...        ...
# 113005        zh         中文
# 113006        zh         中文
# 113007        zh         中文
# 113008        zh         中文
# 113009        zh         中文
#
# [113010 rows x 7 columns]

# %%
len(df_raa)
# Out:
# 113010

# %%
df_raa = df_raa.rename(columns={
    "lang": "Språk",
    "page_title": "Wikipedia-sida",
    "url": "Extern länk",
    "wiki_link": "Wikipedia-länk",
    "domain": "Domän"
})

# %%
df_raa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113010 entries, 0 to 113009
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Språk           113010 non-null  object
#  1   Wikipedia-sida  113010 non-null  object
#  2   Extern länk     113010 non-null  object
#  3   Wikipedia-länk  113010 non-null  object
#  4   Domän           113010 non-null  object
#  5   lang_code       113010 non-null  object
#  6   lang_name       113010 non-null  object
# dtypes: object(7)
# memory usage: 6.0+ MB

# %%
import pandas as pd

# --- Stats ---
total_links = len(df_raa)
total_unique_links = df_raa['Extern länk'].nunique()
num_languages = df_raa['Språk'].nunique()
langs_sorted = df_raa['Språk'].value_counts()

print("Total links:", total_links)
print("Total unique links:", total_unique_links)
print("Number of languages:", num_languages)
print("\nLanguages with most links:")
print(langs_sorted.to_string())
# Out:
# Total links: 113010
# Total unique links: 60683
# Number of languages: 59
#
# Languages with most links:
# Språk
# sv        28652
# en        17243
# no        11429
# de         7837
# es         6794
# fi         6212
# da         4465
# ja         4305
# nl         3433
# nn         3148
# eu         3076
# id         2550
# zh         2126
# ro         1984
# gl         1705
# af         1118
# ast         984
# an          845
# simple      509
# vi          455
# lb          405
# nan         386
# bs          384
# hak         331
# gv          321
# ilo         313
# cdo         304
# ms          296
# pl          271
# sco         177
# diq         146
# tl          127
# it          125
# frr         104
# gpe          56
# sc           54
# kaa          53
# tum          52
# tt           45
# min          34
# sq           33
# bcl          22
# se           19
# ha           17
# dtp          14
# av           11
# su           10
# ig           10
# ceb           5
# nds           3
# ace           3
# so            2
# bar           1
# nia           1
# mad           1
# sw            1
# ln            1
# guw           1
# za            1

# %%
from urllib.parse import urlparse
import pandas as pd

# Extract domains
df_raa['domain'] = df_raa['Extern länk'].apply(lambda u: urlparse(u).netloc)

# Count links grouped by domain
links_per_domain = df_raa['domain'].value_counts()

print("Links per domain:")
print(links_per_domain.to_string())
# Out:
# Links per domain:
# domain
# kulturnav.org                     89488
# app.raa.se                         9332
# www.bebyggelseregistret.raa.se     3679
# bebyggelseregistret.raa.se         3256
# www.raa.se                         3105
# www.fmis.raa.se                    2164
# www.kringla.nu                      828
# samla.raa.se                        638
# pub.raa.se                          156
# kmb.raa.se                          118
# www.kms.raa.se                      108
# kringla.nu                           71
# hildebrand.raa.se                    24
# raa.se                               14
# old.raa.se                            7
# materialguiden.raa.se                 4
# fmis.raa.se                           4
# vitalis.raa.se                        4
# kms.raa.se                            3
# www.raa.se:80                         1
# www.dialog.raa.se                     1
# ritreg.raa.se                         1
# agendakulturarv.raa.se                1
# dms.raa.se                            1
# fou-anslag.raa.se                     1
# www.kulturnav.org                     1

# %%
import pandas as pd

# --- Stats ---
total_links = len(df_raa)
total_unique_links = df_raa['Extern länk'].nunique()
num_languages = df_raa['Språk'].nunique()
langs_sorted = df_raa['Språk'].value_counts()

print("Total links:", total_links)
print("Total unique links:", total_unique_links)
print("Number of languages:", num_languages)
print("\nLanguages with most links:")
print(langs_sorted.to_string())
# Out:
# Total links: 113010
# Total unique links: 60683
# Number of languages: 59
#
# Languages with most links:
# Språk
# sv        28652
# en        17243
# no        11429
# de         7837
# es         6794
# fi         6212
# da         4465
# ja         4305
# nl         3433
# nn         3148
# eu         3076
# id         2550
# zh         2126
# ro         1984
# gl         1705
# af         1118
# ast         984
# an          845
# simple      509
# vi          455
# lb          405
# nan         386
# bs          384
# hak         331
# gv          321
# ilo         313
# cdo         304
# ms          296
# pl          271
# sco         177
# diq         146
# tl          127
# it          125
# frr         104
# gpe          56
# sc           54
# kaa          53
# tum          52
# tt           45
# min          34
# sq           33
# bcl          22
# se           19
# ha           17
# dtp          14
# av           11
# su           10
# ig           10
# ceb           5
# nds           3
# ace           3
# so            2
# bar           1
# nia           1
# mad           1
# sw            1
# ln            1
# guw           1
# za            1

# %%
from datetime import date
import os

# Sätt datum
today = date.today().strftime("%Y_%m_%d")

# Se till att katalogen finns
os.makedirs("results", exist_ok=True)

# Bygg filnamn
outfile = f"results/links_raa_{today}.csv"

# Exportera
df_raa.to_csv(outfile, index=False, encoding="utf-8")

print(f"[OK] Exported {len(df_raa)} rows to {outfile}")
# Out:
# [OK] Exported 113010 rows to results/links_raa_2025_11_30.csv

# %%
print(df_raa.columns.tolist())
# Out:
# ['Språk', 'Wikipedia-sida', 'Extern länk', 'Wikipedia-länk', 'Domän', 'lang_code', 'lang_name', 'domain']

# %%
from urllib.parse import urlparse
import pandas as pd

# Extract domain
df_raa['domain'] = df_raa['Extern länk'].apply(lambda u: urlparse(u).netloc)

# Count links grouped by domain
links_per_domain = df_raa['domain'].value_counts()

print("Links per domain:")
print(links_per_domain.to_string())
# Out:
# Links per domain:
# domain
# kulturnav.org                     89488
# app.raa.se                         9332
# www.bebyggelseregistret.raa.se     3679
# bebyggelseregistret.raa.se         3256
# www.raa.se                         3105
# www.fmis.raa.se                    2164
# www.kringla.nu                      828
# samla.raa.se                        638
# pub.raa.se                          156
# kmb.raa.se                          118
# www.kms.raa.se                      108
# kringla.nu                           71
# hildebrand.raa.se                    24
# raa.se                               14
# old.raa.se                            7
# materialguiden.raa.se                 4
# fmis.raa.se                           4
# vitalis.raa.se                        4
# kms.raa.se                            3
# www.raa.se:80                         1
# www.dialog.raa.se                     1
# ritreg.raa.se                         1
# agendakulturarv.raa.se                1
# dms.raa.se                            1
# fou-anslag.raa.se                     1
# www.kulturnav.org                     1

# %%
GITHUB_REPO = "https://github.com/salgo60/Svenskaforsamlingar"
script_name = SCRIPT_NAME

# %%
script_name
# Out:
# 'RAA42_linkroot.ipynb'

# %%
# --- Stats ---
total_links = len(df_raa)
total_unique_links = df_raa["Extern länk"].nunique()
langs_with_hits = sorted(df_raa["Språk"].unique())

num_languages_found = len(langs_with_hits)
num_languages_checked = len(df_wiki)        # alla språk som genomsöktes
num_languages_found = df_raa['Språk'].nunique()

# %%
from pathlib import Path
from datetime import date
import pandas as pd

def save_sortable_html_df_raa(
    df,
    out_dir="results",
    domains=None,
    issue_url="https://github.com/salgo60/SamlaLibris/issues/42",
):
    out_dir = Path(out_dir)
    out_dir.mkdir(exist_ok=True)

    today = date.today().strftime("%Y_%m_%d")
    out_path = out_dir / f"links_raa_{today}.html"
    rerun_ts = datetime.now().strftime("%Y-%m-%d %H:%M:%S")


    domains = domains or [] 

    # Gör länkar klickbara om de finns
    df = df.copy()  
    if "Wikipedia-länk" in df.columns:
        df["Wikipedia-länk"] = df["Wikipedia-länk"].apply(
            lambda x: f'<a href="{x}" target="_blank">{x}</a>' if pd.notna(x) else ""
        )
    if "Extern länk" in df.columns:
        df["Extern länk"] = df["Extern länk"].apply(
            lambda x: f'<a href="{x}" target="_blank">{x}</a>' if pd.notna(x) else ""
        )

    html_table = df.to_html(
        classes="pivot",
        border=0,
        escape=False,   # viktigt för klickbara länkar
        index=False
    )
   
    css = """
    <style>
      body {
        font-family: Arial, sans-serif;
        margin: 20px;
      }
      table.pivot {
        border-collapse: collapse;
        width: 100%;
        font-size: 12px;
      }
      table.pivot th, table.pivot td {
        border: 1px solid #999;
        padding: 6px 8px;
        text-align: left;
        vertical-align: top;
        white-space: normal;
      }
      table.pivot th {
        cursor: pointer;
        background: #f2f2f2;
      }
      table.pivot th:hover {
        background: #e2e2e2;
      } 
      table.pivot thead th {
          position: sticky;
          top: 0;
          background: #f2f2f2;
          z-index: 2;
        }
        
        /* Sorting indicators */
        table.pivot th::after {
          content: "";
          float: right;
          opacity: 0.4;
        }
        
        table.pivot th.sorted-asc::after {
          content: " ▲";
        }
        
        table.pivot th.sorted-desc::after {
          content: " ▼";
        }
          .meta {
            background: #f8f8f8;
            border: 1px solid #ccc;
            padding: 12px;
            margin-bottom: 20px;
            font-size: 13px;
          }
          .meta h2 {
            margin-top: 0;
          }
          .meta ul {
            margin: 0;
            padding-left: 18px;
          }
    </style>
    """

    js = """
    <script>
    document.addEventListener('DOMContentLoaded', () => {
        document.querySelectorAll("table.pivot th").forEach((header, colIndex) => {
            header.addEventListener("click", () => {
                const table = header.closest("table");
                const tbody = table.querySelector("tbody");
                const rows = Array.from(tbody.querySelectorAll("tr"));
                const asc = !header.classList.contains("sorted-asc");

                rows.sort((a, b) => {
                    const A = a.children[colIndex].innerText.trim();
                    const B = b.children[colIndex].innerText.trim();

                    const numA = parseFloat(A.replace(",", ".")) || null;
                    const numB = parseFloat(B.replace(",", ".")) || null;

                    if (numA !== null && numB !== null) {
                        return asc ? numA - numB : numB - numA;
                    }
                    return asc ? A.localeCompare(B) : B.localeCompare(A);
                });

                table.querySelectorAll("th").forEach(th =>
                    th.classList.remove("sorted-asc","sorted-desc")
                );
                header.classList.add(asc ? "sorted-asc" : "sorted-desc");

                rows.forEach(row => tbody.appendChild(row));
            });
        });
    });
    </script>
    """
    meta_html = f"""
    <div class="meta">
      <h2>Metadata</h2>
    
      <p><strong>Rerun:</strong> {rerun_ts}</p>
      <p><strong>Script:</strong>
         <a href="{SCRIPT_URL}" target="_blank">{SCRIPT_NAME}</a>
      </p>
      <p><strong>Issue:</strong>
         <a href="{issue_url}" target="_blank">{issue_url.split('/')[-1]}</a>
      </p>
    
      <p><strong>Datakällor:</strong></p>
      <div class="meta-indent">
        Wikidata<br>
        MediaWiki API – exturlusage
      </div>
    
      <p><strong>Parametrar:</strong></p>
      <div class="meta-indent">
        Språkfilter: exkluderar "special"
      </div>
    
      <p><strong>Antal språk genomsökta:</strong> {num_languages_checked}</p>
      <p><strong>Antal språk med träffar:</strong> {num_languages_found}</p>
      <p><strong>Wikipedia-språk med träffar:</strong> {", ".join(langs_with_hits)}</p>
      <p><strong>Totala länkar:</strong> {total_links}</p>
      <p><strong>Unika länkar:</strong> {total_unique_links}</p>
    </div>
    """
    
    html = f"""
    <html>
    <head>
      <meta charset="utf-8">
      <title>RAÄ links in Wikipedia</title>
      {css}
    </head>
    <body>
      <h1>Wikipedia → RAÄ</h1>
      {meta_html}
      <p>Sorterbar tabell. Klicka på kolumnrubriker för sortering.</p>
      {html_table}
      {js}
    </body>
    </html>
    """

    out_path.write_text(html, encoding="utf-8")
    print(f"✅ HTML skapad: {out_path}")

# %%
save_sortable_html_df_raa(df_raa)
# Out:
# ✅ HTML skapad: results/links_raa_2025_11_30.html

# %%
 # End timer and calculate duration
end_time = time.time()
elapsed_time = end_time - start_time# Bygg audit-lager för den här etappen

# Print current date and total time
print("Date:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
minutes, seconds = divmod(elapsed_time, 60)
print("Total time elapsed: {:02.0f} minutes {:05.2f} seconds".format(minutes, seconds))
# Out:
# Date: 2025-11-30 13:47:13
# Total time elapsed: 05 minutes 54.70 seconds
