# %% [markdown]
# * [#42](https://github.com/salgo60/SamlaLibris/issues/42)
# * denna Notebook [RAA42_linkroot.ipynb](https://github.com/salgo60/SamlaLibris/blob/master/notebook/RAA42_linkroot.ipynb)
#    *  [links_raa_2025_11_30.html](https://salgo60.github.io/SamlaLibris/notebook/results/links_raa_2025_11_30.html)

# %%
import time

from datetime import datetime

now = datetime.now()
timestamp = now.timestamp()

start_time = time.time()
print("Start:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Start: 2025-11-30 18:48:56

# %%
SCRIPT_NAME = "RAA42_linkroot.ipynb"
SCRIPT_URL = (
    "https://github.com/salgo60/SamlaLibris/"
    "blob/master/Notebook/RAA42_linkroot.ipynb"
)

# %%
import os

# Get the current working directory
current_directory = os.getcwd()
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: /Users/salgo/Documents/GitHub/SamlaLibris/notebook

# %%
def read_domains(file_path):
    print(f"[DEBUG] Reading domains from: {file_path}")
    print(f"[DEBUG] Current Working Directory: {current_directory}")

    df = pd.read_csv(file_path, header=0)   # <- skip header row
    domains_list = df.iloc[:, 0].dropna().unique().tolist()
    print(f"[DEBUG] Found {len(domains_list)} domains.")
    return domains_list

# %%
import requests

def fetch_sitematrix_df():
    url = "https://meta.wikimedia.org/w/api.php"
    params = {
        "action": "sitematrix",
        "format": "json"
    }
    headers = {
        "User-Agent": "salgo60-language-fetcher/1.0 (salgo60@msn.com)"
    }

    print("[DEBUG] Fetching sitematrix…")
    r = requests.get(url, params=params, headers=headers)
    r.raise_for_status()

    if "application/json" not in r.headers.get("Content-Type", ""):
        raise ValueError("Server returned non-JSON response")

    data = r.json()["sitematrix"]

    rows = []

    # --- language-specific sites ---
    for key, lang_block in data.items():
        if not key.isdigit():
            continue  # skip "count", "specials"

        lang_code = lang_block.get("code")
        lang_name = lang_block.get("name")

        for site in lang_block.get("site", []):
            rows.append({
                "lang_code": lang_code,
                "lang_name": lang_name,
                "project": site.get("project"),
                "url": site.get("url"),
                "dbname": site.get("dbname"),
                "site_name": site.get("sitename"),
                "closed": site.get("closed", False)
            })

    # --- special wikis (Wikidata, Commons, Meta, etc.) ---
    for site in data.get("specials", []):
        rows.append({
            "lang_code": "special",
            "lang_name": "special",
            "project": site.get("project"),
            "url": site.get("url"),
            "dbname": site.get("dbname"),
            "site_name": site.get("sitename"),
            "closed": site.get("closed", False)
        })

    return pd.DataFrame(rows)

# %%
import requests
import pandas as pd


HEADERS = {
    "User-Agent": "salgo60-language-fetcher/2.0 (https://github.com/salgo60)"
}


df_wiki = fetch_sitematrix_df()
df_wiki["closed"] = df_wiki["closed"].fillna(False).astype(bool)
df_wiki = df_wiki[df_wiki["site_name"] == "Wikipedia"]
df_wiki.head()
# Out:
# [DEBUG] Fetching sitematrix…
#    lang_code  lang_name project                        url   dbname  \
# 0         aa   Qafár af    None   https://aa.wikipedia.org   aawiki
# 5        ace       Acèh    None  https://ace.wikipedia.org  acewiki
# 7         af  Afrikaans    None   https://af.wikipedia.org   afwiki
# 11        ak       None    None   https://ak.wikipedia.org   akwiki
# 18       ami    Pangcah    None  https://ami.wikipedia.org  amiwiki
#
#     site_name  closed
# 0   Wikipedia   False
# 5   Wikipedia   False
# 7   Wikipedia   False
# 11  Wikipedia   False
# 18  Wikipedia   False

# %%
df_wiki.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 207 entries, 0 to 1061
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lang_code  207 non-null    object
#  1   lang_name  206 non-null    object
#  2   project    0 non-null      object
#  3   url        207 non-null    object
#  4   dbname     207 non-null    object
#  5   site_name  207 non-null    object
#  6   closed     207 non-null    bool
# dtypes: bool(1), object(6)
# memory usage: 11.5+ KB

# %%
len(df_wiki)
# Out:
# 207

# %%
# -----------------------------------------------------------
# Fetch exturlusage entries for one lang/domain
# -----------------------------------------------------------
def fetch_exturlusage(lang, domain):
    base = f"https://{lang}.wikipedia.org/w/api.php"
    params = {
        "action": "query",
        "format": "json",
        "list": "exturlusage",
        "euquery": domain,
        "eulimit": "max"
    }
    while True:
        r = session.get(base, params=params, timeout=10)
        try:
            data = r.json()
        except ValueError:
            print(f"[WARN] {lang}: JSON decode failed")
            break

        for item in data.get("query", {}).get("exturlusage", []):
            yield {
                "lang": lang,
                "page_title": item.get("title"),
                "url": item.get("url"),
                "wiki_link": f"https://{lang}.wikipedia.org/wiki/{item.get('title').replace(' ', '_')}"
            }

        if "continue" not in data:
            break
        params.update(data["continue"])
        time.sleep(0.3)

# %%
import os
import time
import random
import requests
import pandas as pd
from urllib.parse import urlparse
from tqdm.notebook import tqdm
file_path_domain = "sources/domains.csv"
domains = read_domains(file_path_domain)
print(domains)
# Out:
# [DEBUG] Reading domains from: sources/domains.csv
# [DEBUG] Current Working Directory: /Users/salgo/Documents/GitHub/SamlaLibris/notebook
# [DEBUG] Found 6 domains.
# ['raa.se', 'kringla.nu', 'fornsok.se', 'kulturnav.org', 'k-samsok.se', 'kulturmiljolagen.se']

# %%
# -------------------------
# Session & helpers
# -------------------------
session = requests.Session()
session.headers.update(
    {"User-Agent": "RAA-LinkAudit/1.0 salgo60@msn.com"}
)

# Filter out special languages
df_wiki_lang = df_wiki[df_wiki["lang_code"] != "special"]
print("Antal Språk:", len(df_wiki_lang))

results = []

for _, row in df_wiki_lang.iterrows():
    lang = row["lang_code"]
    url = row["url"]
    lang_name = row["lang_name"]

    before = len(results)
    for d in domains:
        #print(lang, url, lang_name, d)
        before_domain = len(results)


        for entry in fetch_exturlusage(lang, d):
            entry["domain"] = d
            entry["lang_code"] = lang
            entry["lang_name"] = lang_name
            results.append(entry)
        added_domain = len(results) - before_domain
        if added_domain > 0:
            print("\t",d, "- nr added domain: ", added_domain)

    added = len(results) - before
    print(lang, lang_name, "- nr added lang: ", added)
# Out:
# Antal Språk: 184
# aa Qafár af - nr added lang:  0
# 	 kulturnav.org - nr added domain:  3
# ace Acèh - nr added lang:  3
# 	 raa.se - nr added domain:  1
# 	 kulturnav.org - nr added domain:  1117
# af Afrikaans - nr added lang:  1118
# ak None - nr added lang:  0
# ami Pangcah - nr added lang:  0
# 	 kulturnav.org - nr added domain:  845
# an aragonés - nr added lang:  845
# 	 raa.se - nr added domain:  2
# 	 kulturnav.org - nr added domain:  982
# ast asturianu - nr added lang:  984
# 	 kulturnav.org - nr added domain:  11
# av авар - nr added lang:  11
# avk Kotava - nr added lang:  0
# ay Aymar aru - nr added lang:  0
# 	 kulturnav.org - nr added domain:  1
# bar Boarisch - nr added lang:  1
# bbc Batak Toba - nr added lang:  0
# 	 kulturnav.org - nr added domain:  22
# bcl Bikol Central - nr added lang:  22
# bi Bislama - nr added lang:  0
# bm bamanankan - nr added lang:  0
# bo བོད་ཡིག - nr added lang:  0
# br brezhoneg - nr added lang:  0
# 	 raa.se - nr added domain:  1
# 	 kulturnav.org - nr added domain:  383
# bs bosanski - nr added lang:  384
# btm Batak Mandailing - nr added lang:  0
# bug Basa Ugi - nr added lang:  0
# bxr буряад - nr added lang:  0
# cbk-zam Chavacano de Zamboanga - nr added lang:  0
# 	 kulturnav.org - nr added domain:  304
# cdo 閩東語 / Mìng-dĕ̤ng-ngṳ̄ - nr added lang:  304
# 	 kulturnav.org - nr added domain:  5
# ceb Cebuano - nr added lang:  5
# ch Chamoru - nr added lang:  0
# cho Chahta anumpa - nr added lang:  0
# chr ᏣᎳᎩ - nr added lang:  0
# co corsu - nr added lang:  0
# cr Nēhiyawēwin / ᓀᐦᐃᔭᐍᐏᐣ - nr added lang:  0
# csb kaszëbsczi - nr added lang:  0
# 	 raa.se - nr added domain:  284
# 	 kringla.nu - nr added domain:  2
# 	 kulturnav.org - nr added domain:  4179
# da dansk - nr added lang:  4465
# 	 raa.se - nr added domain:  7803
# 	 kringla.nu - nr added domain:  10
# 	 kulturnav.org - nr added domain:  24
# de Deutsch - nr added lang:  7837
# din Thuɔŋjäŋ - nr added lang:  0
# 	 kulturnav.org - nr added domain:  146
# diq Zazaki - nr added lang:  146
# 	 kulturnav.org - nr added domain:  14
# dtp Kadazandusun - nr added lang:  14
# dz ཇོང་ཁ - nr added lang:  0
# ee eʋegbe - nr added lang:  0
# eml emiliàn e rumagnòl - nr added lang:  0
# 	 raa.se - nr added domain:  968
# 	 kringla.nu - nr added domain:  48
# 	 kulturnav.org - nr added domain:  16227
# en English - nr added lang:  17243
# 	 raa.se - nr added domain:  116
# 	 kringla.nu - nr added domain:  5
# 	 kulturnav.org - nr added domain:  6673
# es español - nr added lang:  6794
# 	 raa.se - nr added domain:  7
# 	 kulturnav.org - nr added domain:  3069
# eu euskara - nr added lang:  3076
# fat mfantse - nr added lang:  0
# ff Fulfulde - nr added lang:  0
# 	 raa.se - nr added domain:  339
# 	 kringla.nu - nr added domain:  5
# 	 kulturnav.org - nr added domain:  5868
# fi suomi - nr added lang:  6212
# fj Na Vosa Vakaviti - nr added lang:  0
# fo føroyskt - nr added lang:  0
# 	 kulturnav.org - nr added domain:  104
# frr Nordfriisk - nr added lang:  104
# 	 raa.se - nr added domain:  50
# 	 kulturnav.org - nr added domain:  1655
# gl galego - nr added lang:  1705
# glk گیلکی - nr added lang:  0
# gor Bahasa Hulontalo - nr added lang:  0
# got 𐌲𐌿𐍄𐌹𐍃𐌺 - nr added lang:  0
# 	 kulturnav.org - nr added domain:  56
# gpe Ghanaian Pidgin - nr added lang:  56
# [WARN] gsw: JSON decode failed
# [WARN] gsw: JSON decode failed
# [WARN] gsw: JSON decode failed
# [WARN] gsw: JSON decode failed
# [WARN] gsw: JSON decode failed
# [WARN] gsw: JSON decode failed
# gsw Alemannisch - nr added lang:  0
# 	 kulturnav.org - nr added domain:  1
# guw gungbe - nr added lang:  1
# 	 kulturnav.org - nr added domain:  321
# gv Gaelg - nr added lang:  321
# 	 kringla.nu - nr added domain:  1
# 	 kulturnav.org - nr added domain:  16
# ha Hausa - nr added lang:  17
# 	 kulturnav.org - nr added domain:  331
# hak 客家語 / Hak-kâ-ngî - nr added lang:  331
# haw Hawaiʻi - nr added lang:  0
# hif Fiji Hindi - nr added lang:  0
# ho Hiri Motu - nr added lang:  0
# hz Otsiherero - nr added lang:  0
# ia interlingua - nr added lang:  0
# iba Jaku Iban - nr added lang:  0
# 	 raa.se - nr added domain:  11
# 	 kulturnav.org - nr added domain:  2539
# id Bahasa Indonesia - nr added lang:  2550
# ie Interlingue - nr added lang:  0
# 	 kulturnav.org - nr added domain:  10
# ig Igbo - nr added lang:  10
# ii ꆇꉙ - nr added lang:  0
# ik Iñupiatun - nr added lang:  0
# 	 kulturnav.org - nr added domain:  313
# ilo Ilokano - nr added lang:  313
# is íslenska - nr added lang:  0
# 	 raa.se - nr added domain:  105
# 	 kringla.nu - nr added domain:  2
# 	 kulturnav.org - nr added domain:  18
# it italiano - nr added lang:  125
# 	 raa.se - nr added domain:  24
# 	 kringla.nu - nr added domain:  1
# 	 kulturnav.org - nr added domain:  4280
# ja 日本語 - nr added lang:  4305
# jbo la .lojban. - nr added lang:  0
# 	 kulturnav.org - nr added domain:  53
# kaa Qaraqalpaqsha - nr added lang:  53
# kab Taqbaylit - nr added lang:  0
# kcg Tyap - nr added lang:  0
# kg Kongo - nr added lang:  0
# ki Gĩkũyũ - nr added lang:  0
# kj Kwanyama - nr added lang:  0
# kl kalaallisut - nr added lang:  0
# knc Yerwa Kanuri - nr added lang:  0
# kr kanuri - nr added lang:  0
# ksh Ripoarisch - nr added lang:  0
# kv коми - nr added lang:  0
# kw kernowek - nr added lang:  0
# 	 kulturnav.org - nr added domain:  405
# lb Lëtzebuergesch - nr added lang:  405
# lg Luganda - nr added lang:  0
# li Limburgs - nr added lang:  0
# lij Ligure - nr added lang:  0
# lld Ladin - nr added lang:  0
# lmo lombard - nr added lang:  0
# 	 raa.se - nr added domain:  1
# ln lingála - nr added lang:  1
# 	 kulturnav.org - nr added domain:  1
# mad Madhurâ - nr added lang:  1
# map-bms Basa Banyumasan - nr added lang:  0
# mg Malagasy - nr added lang:  0
# mh Ebon - nr added lang:  0
# mi Māori - nr added lang:  0
# 	 kulturnav.org - nr added domain:  34
# min Minangkabau - nr added lang:  34
# 	 kulturnav.org - nr added domain:  296
# ms Bahasa Melayu - nr added lang:  296
# mus Mvskoke - nr added lang:  0
# na Dorerin Naoero - nr added lang:  0
# 	 kulturnav.org - nr added domain:  386
# nan 閩南語 / Bân-lâm-gí - nr added lang:  386
# nap Napulitano - nr added lang:  0
# 	 raa.se - nr added domain:  3
# nds Plattdüütsch - nr added lang:  3
# nds-nl Nedersaksies - nr added lang:  0
# new नेपाल भाषा - nr added lang:  0
# ng Oshiwambo - nr added lang:  0
# 	 kulturnav.org - nr added domain:  1
# nia Li Niha - nr added lang:  1
# 	 raa.se - nr added domain:  7
# 	 kulturnav.org - nr added domain:  3426
# nl Nederlands - nr added lang:  3433
# 	 raa.se - nr added domain:  48
# 	 kringla.nu - nr added domain:  1
# 	 kulturnav.org - nr added domain:  3099
# nn norsk nynorsk - nr added lang:  3148
# 	 raa.se - nr added domain:  172
# 	 kringla.nu - nr added domain:  83
# 	 kulturnav.org - nr added domain:  11174
# no norsk - nr added lang:  11429
# nov Novial - nr added lang:  0
# nrm Nouormand - nr added lang:  0
# nso Sesotho sa Leboa - nr added lang:  0
# nup Nupe - nr added lang:  0
# nv Diné bizaad - nr added lang:  0
# ny Chi-Chewa - nr added lang:  0
# om Oromoo - nr added lang:  0
# pag Pangasinan - nr added lang:  0
# pam Kapampangan - nr added lang:  0
# pap Papiamentu - nr added lang:  0
# pcd Picard - nr added lang:  0
# pcm Naijá - nr added lang:  0
# pdc Deitsch - nr added lang:  0
# pfl Pälzisch - nr added lang:  0
# pi पालि - nr added lang:  0
# pih Norfuk / Pitkern - nr added lang:  0
# 	 raa.se - nr added domain:  262
# 	 kringla.nu - nr added domain:  1
# 	 kulturnav.org - nr added domain:  8
# pl polski - nr added lang:  271
# pms Piemontèis - nr added lang:  0
# pwn pinayuanan - nr added lang:  0
# qu Runa Simi - nr added lang:  0
# rm rumantsch - nr added lang:  0
# rn ikirundi - nr added lang:  0
# 	 raa.se - nr added domain:  5
# 	 kulturnav.org - nr added domain:  1979
# ro română - nr added lang:  1984
# roa-tara tarandíne - nr added lang:  0
# [WARN] rup: JSON decode failed
# [WARN] rup: JSON decode failed
# [WARN] rup: JSON decode failed
# [WARN] rup: JSON decode failed
# [WARN] rup: JSON decode failed
# [WARN] rup: JSON decode failed
# rup armãneashti - nr added lang:  0
# rw Ikinyarwanda - nr added lang:  0
# 	 kulturnav.org - nr added domain:  55
# sc sardu - nr added lang:  55
# scn sicilianu - nr added lang:  0
# 	 kulturnav.org - nr added domain:  177
# sco Scots - nr added lang:  177
# 	 kulturnav.org - nr added domain:  19
# se davvisámegiella - nr added lang:  19
# sg Sängö - nr added lang:  0
# sgs žemaitėška - nr added lang:  0
# shi Taclḥit - nr added lang:  0
# 	 raa.se - nr added domain:  19
# 	 kringla.nu - nr added domain:  1
# 	 kulturnav.org - nr added domain:  489
# simple Simple English - nr added lang:  509
# sm Gagana Samoa - nr added lang:  0
# smn anarâškielâ - nr added lang:  0
# sn chiShona - nr added lang:  0
# 	 kulturnav.org - nr added domain:  2
# so Soomaaliga - nr added lang:  2
# 	 raa.se - nr added domain:  7
# 	 kringla.nu - nr added domain:  1
# 	 kulturnav.org - nr added domain:  25
# sq shqip - nr added lang:  33
# srn Sranantongo - nr added lang:  0
# ss SiSwati - nr added lang:  0
# st Sesotho - nr added lang:  0
# stq Seeltersk - nr added lang:  0
# 	 kulturnav.org - nr added domain:  10
# su Sunda - nr added lang:  10
# 	 raa.se - nr added domain:  12354
# 	 kringla.nu - nr added domain:  735
# 	 kulturnav.org - nr added domain:  15564
# sv svenska - nr added lang:  28653
# 	 kringla.nu - nr added domain:  1
# sw Kiswahili - nr added lang:  1
# szl ślůnski - nr added lang:  0
# tet tetun - nr added lang:  0
# 	 kulturnav.org - nr added domain:  127
# tl Tagalog - nr added lang:  127
# tn Setswana - nr added lang:  0
# to lea faka-Tonga - nr added lang:  0
# tpi Tok Pisin - nr added lang:  0
# ts Xitsonga - nr added lang:  0
# 	 kulturnav.org - nr added domain:  45
# tt татарча / tatarça - nr added lang:  45
# 	 kulturnav.org - nr added domain:  52
# tum chiTumbuka - nr added lang:  52
# tw Twi - nr added lang:  0
# ty reo tahiti - nr added lang:  0
# ug ئۇيغۇرچە / Uyghurche - nr added lang:  0
# ve Tshivenda - nr added lang:  0
# vec vèneto - nr added lang:  0
# 	 raa.se - nr added domain:  19
# 	 kringla.nu - nr added domain:  1
# 	 kulturnav.org - nr added domain:  435
# vi Tiếng Việt - nr added lang:  455
# vls West-Vlams - nr added lang:  0
# vro võro - nr added lang:  0
# wa walon - nr added lang:  0
# war Winaray - nr added lang:  0
# wo Wolof - nr added lang:  0
# xal хальмг - nr added lang:  0
# xh isiXhosa - nr added lang:  0
# yo Yorùbá - nr added lang:  0
# 	 kulturnav.org - nr added domain:  1
# za Vahcuengh - nr added lang:  1
# zea Zeêuws - nr added lang:  0
# 	 raa.se - nr added domain:  14
# 	 kringla.nu - nr added domain:  1
# 	 kulturnav.org - nr added domain:  2111
# zh 中文 - nr added lang:  2126
# zu isiZulu - nr added lang:  0

# %%
#results

# %%
domains
# Out:
# ['raa.se',
#  'kringla.nu',
#  'fornsok.se',
#  'kulturnav.org',
#  'k-samsok.se',
#  'kulturmiljolagen.se']

# %%
df_raa = pd.DataFrame(results)

# %%
df_raa
# Out:
#        lang          page_title  \
# 0       ace       Leonard Cohen
# 1       ace    Agnetha Fältskog
# 2       ace  Anni-Frid Lyngstad
# 3        af               Adils
# 4        af      Oscar Niemeyer
# ...     ...                 ...
# 113007   zh         阿克塞利·加伦-卡莱拉
# 113008   zh             路易-腓力一世
# 113009   zh        腓力二世 (奥尔良公爵)
# 113010   zh                  日本
# 113011   zh         約翰·米爾斯 (演員)
#
#                                                       url  \
# 0       http://kulturnav.org/language/en/7e908441-ad8d...
# 1       http://kulturnav.org/language/en/1718a400-a2bc...
# 2       http://kulturnav.org/language/en/a75e48ae-e70f...
# 3       http://www.raa.se/cms/extern/se_och_besoka/sev...
# 4       http://kulturnav.org/6aa00405-f813-4e04-96b2-1...
# ...                                                   ...
# 113007  http://kulturnav.org/05592038-b220-4690-a4b0-2...
# 113008  http://kulturnav.org/7996dfff-be63-44e5-a183-b...
# 113009  http://kulturnav.org/3ae5117c-3ef8-4d33-9eea-9...
# 113010  http://kulturnav.org/de944dd7-838e-46d0-a342-b...
# 113011  http://kulturnav.org/04ac3136-7fd5-470d-bb3e-0...
#
#                                                 wiki_link         domain  \
# 0            https://ace.wikipedia.org/wiki/Leonard_Cohen  kulturnav.org
# 1         https://ace.wikipedia.org/wiki/Agnetha_Fältskog  kulturnav.org
# 2       https://ace.wikipedia.org/wiki/Anni-Frid_Lyngstad  kulturnav.org
# 3                     https://af.wikipedia.org/wiki/Adils         raa.se
# 4            https://af.wikipedia.org/wiki/Oscar_Niemeyer  kulturnav.org
# ...                                                   ...            ...
# 113007          https://zh.wikipedia.org/wiki/阿克塞利·加伦-卡莱拉  kulturnav.org
# 113008              https://zh.wikipedia.org/wiki/路易-腓力一世  kulturnav.org
# 113009         https://zh.wikipedia.org/wiki/腓力二世_(奥尔良公爵)  kulturnav.org
# 113010                   https://zh.wikipedia.org/wiki/日本  kulturnav.org
# 113011          https://zh.wikipedia.org/wiki/約翰·米爾斯_(演員)  kulturnav.org
#
#        lang_code  lang_name
# 0            ace       Acèh
# 1            ace       Acèh
# 2            ace       Acèh
# 3             af  Afrikaans
# 4             af  Afrikaans
# ...          ...        ...
# 113007        zh         中文
# 113008        zh         中文
# 113009        zh         中文
# 113010        zh         中文
# 113011        zh         中文
#
# [113012 rows x 7 columns]

# %%
len(df_raa)
# Out:
# 113012

# %%
df_raa = df_raa.rename(columns={
    "lang": "Språk",
    "page_title": "Wikipedia-sida",
    "url": "Extern länk",
    "wiki_link": "Wikipedia-länk",
    "domain": "Domän"
})

# %%
df_raa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113012 entries, 0 to 113011
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Språk           113012 non-null  object
#  1   Wikipedia-sida  113012 non-null  object
#  2   Extern länk     113012 non-null  object
#  3   Wikipedia-länk  113012 non-null  object
#  4   Domän           113012 non-null  object
#  5   lang_code       113012 non-null  object
#  6   lang_name       113012 non-null  object
# dtypes: object(7)
# memory usage: 6.0+ MB

# %%
import pandas as pd

# --- Stats ---
total_links = len(df_raa)
total_unique_links = df_raa['Extern länk'].nunique()
num_languages = df_raa['Språk'].nunique()
langs_sorted = df_raa['Språk'].value_counts()

print("Total links:", total_links)
print("Total unique links:", total_unique_links)
print("Number of languages:", num_languages)
print("\nLanguages with most links:")
print(langs_sorted.to_string())
# Out:
# Total links: 113012
# Total unique links: 60683
# Number of languages: 59
#
# Languages with most links:
# Språk
# sv        28653
# en        17243
# no        11429
# de         7837
# es         6794
# fi         6212
# da         4465
# ja         4305
# nl         3433
# nn         3148
# eu         3076
# id         2550
# zh         2126
# ro         1984
# gl         1705
# af         1118
# ast         984
# an          845
# simple      509
# vi          455
# lb          405
# nan         386
# bs          384
# hak         331
# gv          321
# ilo         313
# cdo         304
# ms          296
# pl          271
# sco         177
# diq         146
# tl          127
# it          125
# frr         104
# gpe          56
# sc           55
# kaa          53
# tum          52
# tt           45
# min          34
# sq           33
# bcl          22
# se           19
# ha           17
# dtp          14
# av           11
# su           10
# ig           10
# ceb           5
# nds           3
# ace           3
# so            2
# bar           1
# nia           1
# mad           1
# sw            1
# ln            1
# guw           1
# za            1

# %%
from urllib.parse import urlparse
import pandas as pd

# Extract domains
df_raa['domain'] = df_raa['Extern länk'].apply(lambda u: urlparse(u).netloc)

# Count links grouped by domain
links_per_domain = df_raa['domain'].value_counts()

print("Links per domain:")
print(links_per_domain.to_string())
# Out:
# Links per domain:
# domain
# kulturnav.org                     89490
# app.raa.se                         9332
# www.bebyggelseregistret.raa.se     3679
# bebyggelseregistret.raa.se         3256
# www.raa.se                         3105
# www.fmis.raa.se                    2164
# www.kringla.nu                      828
# samla.raa.se                        638
# pub.raa.se                          156
# kmb.raa.se                          118
# www.kms.raa.se                      108
# kringla.nu                           71
# hildebrand.raa.se                    24
# raa.se                               14
# old.raa.se                            7
# materialguiden.raa.se                 4
# fmis.raa.se                           4
# vitalis.raa.se                        4
# kms.raa.se                            3
# www.raa.se:80                         1
# www.dialog.raa.se                     1
# ritreg.raa.se                         1
# agendakulturarv.raa.se                1
# dms.raa.se                            1
# fou-anslag.raa.se                     1
# www.kulturnav.org                     1

# %%
import pandas as pd

# --- Stats ---
total_links = len(df_raa)
total_unique_links = df_raa['Extern länk'].nunique()
num_languages = df_raa['Språk'].nunique()
langs_sorted = df_raa['Språk'].value_counts()

print("Total links:", total_links)
print("Total unique links:", total_unique_links)
print("Number of languages:", num_languages)
print("\nLanguages with most links:")
print(langs_sorted.to_string())
# Out:
# Total links: 113012
# Total unique links: 60683
# Number of languages: 59
#
# Languages with most links:
# Språk
# sv        28653
# en        17243
# no        11429
# de         7837
# es         6794
# fi         6212
# da         4465
# ja         4305
# nl         3433
# nn         3148
# eu         3076
# id         2550
# zh         2126
# ro         1984
# gl         1705
# af         1118
# ast         984
# an          845
# simple      509
# vi          455
# lb          405
# nan         386
# bs          384
# hak         331
# gv          321
# ilo         313
# cdo         304
# ms          296
# pl          271
# sco         177
# diq         146
# tl          127
# it          125
# frr         104
# gpe          56
# sc           55
# kaa          53
# tum          52
# tt           45
# min          34
# sq           33
# bcl          22
# se           19
# ha           17
# dtp          14
# av           11
# su           10
# ig           10
# ceb           5
# nds           3
# ace           3
# so            2
# bar           1
# nia           1
# mad           1
# sw            1
# ln            1
# guw           1
# za            1

# %%
from datetime import date
import os

# Sätt datum
today = date.today().strftime("%Y_%m_%d")

# Se till att katalogen finns
os.makedirs("results", exist_ok=True)

# Bygg filnamn
outfile = f"results/links_raa_{today}.csv"

# Exportera
df_raa.to_csv(outfile, index=False, encoding="utf-8")

print(f"[OK] Exported {len(df_raa)} rows to {outfile}")
# Out:
# [OK] Exported 113012 rows to results/links_raa_2025_11_30.csv

# %%
print(df_raa.columns.tolist())
# Out:
# ['Språk', 'Wikipedia-sida', 'Extern länk', 'Wikipedia-länk', 'Domän', 'lang_code', 'lang_name', 'domain']

# %%
from urllib.parse import urlparse
import pandas as pd

# Extract domain
df_raa['domain'] = df_raa['Extern länk'].apply(lambda u: urlparse(u).netloc)

# Count links grouped by domain
links_per_domain = df_raa['domain'].value_counts()

print("Links per domain:")
print(links_per_domain.to_string())
# Out:
# Links per domain:
# domain
# kulturnav.org                     89490
# app.raa.se                         9332
# www.bebyggelseregistret.raa.se     3679
# bebyggelseregistret.raa.se         3256
# www.raa.se                         3105
# www.fmis.raa.se                    2164
# www.kringla.nu                      828
# samla.raa.se                        638
# pub.raa.se                          156
# kmb.raa.se                          118
# www.kms.raa.se                      108
# kringla.nu                           71
# hildebrand.raa.se                    24
# raa.se                               14
# old.raa.se                            7
# materialguiden.raa.se                 4
# fmis.raa.se                           4
# vitalis.raa.se                        4
# kms.raa.se                            3
# www.raa.se:80                         1
# www.dialog.raa.se                     1
# ritreg.raa.se                         1
# agendakulturarv.raa.se                1
# dms.raa.se                            1
# fou-anslag.raa.se                     1
# www.kulturnav.org                     1

# %%
GITHUB_REPO = "https://github.com/salgo60/Svenskaforsamlingar"
script_name = SCRIPT_NAME

# %%
script_name

# %%
# --- Stats ---
total_links = len(df_raa)
total_unique_links = df_raa["Extern länk"].nunique()
langs_with_hits = sorted(df_raa["Språk"].unique())

num_languages_found = len(langs_with_hits)
num_languages_checked = len(df_wiki)        # alla språk som genomsöktes
num_languages_found = df_raa['Språk'].nunique()

# %%
from pathlib import Path
from datetime import date
import pandas as pd

def save_sortable_html_df_raa(
    df,
    out_dir="results",
    domains=None,
    issue_url="https://github.com/salgo60/SamlaLibris/issues/42",
):
    out_dir = Path(out_dir)
    out_dir.mkdir(exist_ok=True)

    today = date.today().strftime("%Y_%m_%d")
    out_path = out_dir / f"links_raa_{today}.html"
    rerun_ts = datetime.now().strftime("%Y-%m-%d %H:%M:%S")


    domains = domains or [] 

    # Gör länkar klickbara om de finns
    df = df.copy()  
    if "Wikipedia-länk" in df.columns:
        df["Wikipedia-länk"] = df["Wikipedia-länk"].apply(
            lambda x: f'<a href="{x}" target="_blank">{x}</a>' if pd.notna(x) else ""
        )
    if "Extern länk" in df.columns:
        df["Extern länk"] = df["Extern länk"].apply(
            lambda x: f'<a href="{x}" target="_blank">{x}</a>' if pd.notna(x) else ""
        )

    html_table = df.to_html(
        classes="pivot",
        border=0,
        escape=False,   # viktigt för klickbara länkar
        index=False
    )
   
    css = """
    <style>
      body {
        font-family: Arial, sans-serif;
        margin: 20px;
      }
      table.pivot {
        border-collapse: collapse;
        width: 100%;
        font-size: 12px;
      }
      table.pivot th, table.pivot td {
        border: 1px solid #999;
        padding: 6px 8px;
        text-align: left;
        vertical-align: top;
        white-space: normal;
      }
      table.pivot th {
        cursor: pointer;
        background: #f2f2f2;
      }
      table.pivot th:hover {
        background: #e2e2e2;
      } 
      table.pivot thead th {
          position: sticky;
          top: 0;
          background: #f2f2f2;
          z-index: 2;
        }
        
        /* Sorting indicators */
        table.pivot th::after {
          content: "";
          float: right;
          opacity: 0.4;
        }
        
        table.pivot th.sorted-asc::after {
          content: " ▲";
        }
        
        table.pivot th.sorted-desc::after {
          content: " ▼";
        }
          .meta {
            background: #f8f8f8;
            border: 1px solid #ccc;
            padding: 12px;
            margin-bottom: 20px;
            font-size: 13px;
          }
          .meta h2 {
            margin-top: 0;
          }
          .meta ul {
            margin: 0;
            padding-left: 18px;
          }
    </style>
    """

    js = """
    <script>
    document.addEventListener('DOMContentLoaded', () => {
        document.querySelectorAll("table.pivot th").forEach((header, colIndex) => {
            header.addEventListener("click", () => {
                const table = header.closest("table");
                const tbody = table.querySelector("tbody");
                const rows = Array.from(tbody.querySelectorAll("tr"));
                const asc = !header.classList.contains("sorted-asc");

                rows.sort((a, b) => {
                    const A = a.children[colIndex].innerText.trim();
                    const B = b.children[colIndex].innerText.trim();

                    const numA = parseFloat(A.replace(",", ".")) || null;
                    const numB = parseFloat(B.replace(",", ".")) || null;

                    if (numA !== null && numB !== null) {
                        return asc ? numA - numB : numB - numA;
                    }
                    return asc ? A.localeCompare(B) : B.localeCompare(A);
                });

                table.querySelectorAll("th").forEach(th =>
                    th.classList.remove("sorted-asc","sorted-desc")
                );
                header.classList.add(asc ? "sorted-asc" : "sorted-desc");

                rows.forEach(row => tbody.appendChild(row));
            });
        });
    });
    </script>
    """
    meta_html = f"""
    <div class="meta">
      <h2>Metadata</h2>
    
      <p><strong>Rerun:</strong> {rerun_ts}</p>
      <p><strong>Script:</strong>
         <a href="{SCRIPT_URL}" target="_blank">{SCRIPT_NAME}</a>
      </p>
      <p><strong>Issue:</strong>
         <a href="{issue_url}" target="_blank">{issue_url.split('/')[-1]}</a>
      </p>
    
      <p><strong>Datakällor:</strong></p>
      <div class="meta-indent">
        Wikidata<br>
        MediaWiki API – exturlusage
      </div>
    
      <p><strong>Parametrar:</strong></p>
      <div class="meta-indent">
        Språkfilter: exkluderar "special"
      </div>
    
      <p><strong>Antal språk genomsökta:</strong> {num_languages_checked}</p>
      <p><strong>Antal språk med träffar:</strong> {num_languages_found}</p>
      <p><strong>Wikipedia-språk med träffar:</strong> {", ".join(langs_with_hits)}</p>
      <p><strong>Totala länkar:</strong> {total_links}</p>
      <p><strong>Unika länkar:</strong> {total_unique_links}</p>
    </div>
    """
    
    html = f"""
    <html>
    <head>
      <meta charset="utf-8">
      <title>RAÄ links in Wikipedia</title>
      {css}
    </head>
    <body>
      <h1>Wikipedia → RAÄ</h1>
      {meta_html}
      <p>Sorterbar tabell. Klicka på kolumnrubriker för sortering.</p>
      {html_table}
      {js}
    </body>
    </html>
    """

    out_path.write_text(html, encoding="utf-8")
    print(f"✅ HTML skapad: {out_path}")

# %%
save_sortable_html_df_raa(df_raa)

# %%
 # End timer and calculate duration
end_time = time.time()
elapsed_time = end_time - start_time# Bygg audit-lager för den här etappen

# Print current date and total time
print("Date:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
minutes, seconds = divmod(elapsed_time, 60)
print("Total time elapsed: {:02.0f} minutes {:05.2f} seconds".format(minutes, seconds))
